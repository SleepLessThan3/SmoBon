# %%
# !pytest Test.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.6, pytest-6.1.2, py-1.9.0, pluggy-0.13.1
# rootdir: /home/akang/FinalProject
# collected 5 items
#
# Test.py .....                                                            [100%]
#
# ============================== 5 passed in 0.66s ===============================

# %%
import main

main.()
# I'm not sure what this TypeError is doing here. I never saw it while
# working on notepad++, and it only showed up when I migrated to datahub
# to create a notebook file.
# Out:
#   _____   __  __    ____    ____     ____    _   _
#  / ____| |  \/  |  / __ \  |  _ \   / __ \  | \ | |
# | (___   | \  / | | |  | | | |_) | | |  | | |  \| |
#  \___ \  | |\/| | | |  | | |  _ <  | |  | | | . ` |
#  ____) | | |  | | | |__| | | |_) | | |__| | | |\  |
# |_____/  |_|  |_|  \____/  |____/   \____/  |_| \_|
#
# Welcome to Smobon, the definitely not ripoff of Smogon. What would you like to do?
# ~~~~~~~~~~~~~~~~~~~~
# -Battle
# -Changelog
# -Quit
# ~~~~~~~~~~~~~~~~~~~~
# Battle
#
# Here is a list of all currently available Pokemon. Enter a Pokemon's name to select it, or enter 'Back' to return to the previous menu.
# ~~~~~~~~~~~~~~~~~~~~
# An Onion
# Salamander
# Turtle
# Not A Mouse
# Big Chungus
# Metang
# Land Shark
# Sleep's Glaceon
# ~~~~~~~~~~~~~~~~~~~~
# Sleep's Glaceon
#
# Sleep's Glaceon / Glaceon
# HP	:  140
# Atk	:  72
# Def	:  130
# Sp Atk	:  200
# Sp Def	:  116
# Spd	:  117
#
# Would you like to select this Pokemon?
# ~~~~~~~~~~~~~~~~~~~~
# -Yes
# -No
# ...

# %% [markdown]
# Run box 2 to start. ^^
#
# This program is a simple Pokemon battler. A lot of stuff hasn't been implemented, but you are still able to have a battle with a Pokemon of your choice, with a small selection of different attacking and status moves.
#
# My Python background is just what what I learned this quarter, but I've had coding experience since high school. This project was initially just a small rpg style combat engine that I had thought of on a whim, but ended up being a bigger than I had intended for it to get. I really pushed myself to go as big as I could go, and just barely completed it within the time limit with an all nighter the night before it was due. I had a lot of fun creating the different databases for everything and connecting it all together. I didn't even actually have anything of substance outputting until yesterday night (3/18), as I had just been working on the back end for the entire time. I think the most challenging part for me was the pytest stuff, as I am used to creating a framework for everything, and then having a session of just running my files over and over with different inputs, and fixing all the bugs I could find.
#
# All in all, I had a lot of fun. I think this is the most fun I've had taking a class in a year or two, and I would love to know how I would go about being a TA for COGS 18 in the future.
